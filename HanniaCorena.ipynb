# %% [markdown]
# ## comencé con la 2 porque la 1 la vi muy dificil

# %% [markdown]
# inventario (lista de diccionarios): Un atributo para almacenar los productos en el inventario. Cada
# producto debe ser representado como un diccionario con las siguientes claves: 'nombre',
# 'precio', y 'cantidad'. Al principio deberá ser una lista vacía. Ejemplo de como debería ser:

# %%
## pregunta 2, diccionario

DiccionarioDeClientes = {
    "Ana García":
    {"email = ana.garcia@gmail.com","compras"},
    "María López":
    {"email = maria.lopez@gmail.com", "compras"}
}
print(DiccionarioDeClientes)
# Out:
# {'Ana García': {'compras', 'email = ana.garcia@gmail.com'}, 'María López': {'email = maria.lopez@gmail.com', 'compras'}}

# %% [markdown]
# # hice la 1 porque al hacer la 2 me dio la confianza para hacer la 1

# %% [markdown]
# clientes (diccionario): Una estructura para llevar un registro de los clientes de la tienda.

# %%
## pregunta 1, lista de diccionarios

lista_inventario = [
    {
        "nombre":"jersey",
        "precio":500,
        "cantidad":1000
    },
    {
        "nombre":"jumper",
        "precio":750,
        "cantidad":300
    }
]
print(lista_inventario)
# Out:
# [{'nombre': 'jersey', 'precio': 500, 'cantidad': 1000}, {'nombre': 'jumper', 'precio': 750, 'cantidad': 300}]

# %% [markdown]
# # intento fallido de la 3:

# %% [markdown]
# ventas_totales (float): Una variable para llevar un registro de las ventas totales de la tienda.
# Inicialízala con valor 0.

# %%
## pregunta 3 float

#nombre de la variable es ventas, ventas es una tupla y dentro una lista
# creo una tupla de valores que no se pueden cambiar

ventas=([("enero",10.5), ("febrero",20.5), ("marzo",30.5), ("abril",40.5), ("mayo",50.5),("junio",60.5)])

# %%
def calculoVentasSumar(*args):
    print(sum.ventas(float(args)))

# %%
calculoVentasSumar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 calculoVentasSumar()
#
# Cell In[17], line 2, in calculoVentasSumar(*args)
#       1 def calculoVentasSumar(*args):
# ----> 2     print(sum.ventas(float(args)))
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'ventas'

# %% [markdown]
# # intento OK de la 3 pero me falta la variable

# %%
diciembre=0
enero=1.5
febrero=2.5
marzo=3.5
abril=5.5
def sumarVentasTotales():
    print(diciembre+enero+febrero+marzo+abril)

# %%
sumarVentasTotales()
# Out:
# 13.0

# %%
# mes es la variable, fallido de variable para sumar
ventas = [
    {
        "enero": {venta = 1},
        "febrero":2
    }
]
def sumar
# Out:
#   Cell In[73], line 4
#     "enero": {venta = 1},
#               ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
ventasMensuales = {
    "enero":1,
    "febrero":2
}
ventasMensuales
# Out:
# {'enero': 1, 'febrero': 2}

# %%
ventasMensuales.values()
# Out:
# dict_values([1, 2])

# %%
def sumarVentas()
    print()

# %%
## otro intento
num1 = 10
num2 = 30
num3 = 40

# %%
def sumarConParametros(num1,num2,num3):
    print(num1+num2+num3)

# %%
sumarConParametros(num1+num2+num3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 sumarConParametros(num1+num2+num3)
#
# TypeError: sumarConParametros() missing 2 required positional arguments: 'num2' and 'num3'

# %% [markdown]
# ## fin de intentos, me quedo con la linea 67

# %%
## funciones

# %% [markdown]
# Agrega un producto al inventario o actualiza su cantidad si ya existe. Debe recibir el nombre, precio y cantidad del producto como
# parámetros. Itera a través del inventario y compara los nombres de los productos con el nombre proporcionado. Si el producto ya existe, actualiza la cantidad. Si no existe, agrega un nuevo producto al inventario.

# %%
inventarioPorActualizar = [
    {
    "nombre":"Pantalon",
    "precio":25,
    "cantidad":10
},
{   "nombre":"Camisa",
    "precio":15,
    "cantidad":50
}
]

# %%
print(inventarioPorActualizar)
# Out:
# [{'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10}, {'nombre': 'Camisa', 'precio': 15, 'cantidad': 50}]

# %% [markdown]
# # con el imput no pude:

# %%
nuevo_nombre = input("Dime un producto")


inventarioPorActualizar.update({nuevo_nombre})
inventarioPorActualizar
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 4
#       1 nuevo_nombre = input("Dime un producto")
# ----> 4 inventarioPorActualizar.update({nuevo_nombre})
#       5 inventarioPorActualizar
#
# AttributeError: 'list' object has no attribute 'update'

# %%
inventarioPorActualizar.update({"nombre:Calcetin"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 inventarioPorActualizar.update({"nombre:Calcetin"})
#
# AttributeError: 'list' object has no attribute 'update'

# %%
inventarioPorActualizar.update({"nombre": "Calcetin", "precio": 38, "cantidad" , 12})
# Out:
#   Cell In[102], line 1
#     inventarioPorActualizar.update({"nombre": "Calcetin", "precio": 38, "cantidad" , 12})
#                                                                                  ^
# SyntaxError: ':' expected after dictionary key

# %%
inventarioPorActualizar2 = []
for i in inventarioPorActualizar:
    inventarioPorActualizar2.append(input("Dime un producto"))
print(inventarioPorActualizar2)
# Out:
# ['Calcetin', 'Calcetin']

# %% [markdown]
# ## 5 Muestra el inventario de productos con sus detalles.
# # Utiliza un bucle for para recorrer el inventario.

# %%
inventary = [
    {
    "nombre":"Pantalon",
    "precio":25,
    "cantidad":10
},
{   "nombre":"Camisa",
    "precio":15,
    "cantidad":50
}
]

# %%
for i in inventary:
    print(i)
# Out:
# {'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10}
# {'nombre': 'Camisa', 'precio': 15, 'cantidad': 50}

# %% [markdown]
# # 6 Busca un producto en el inventario por nombre y muestra sus
# # detalles si se encuentra. Debe recibir el nombre del producto como parámetro.

# %%
for camisa in inventary:
    print(i)
# Out:
# {'nombre': 'Camisa', 'precio': 15, 'cantidad': 50}
# {'nombre': 'Camisa', 'precio': 15, 'cantidad': 50}

# %% [markdown]
# # 7 Actualiza el stock de un producto en el inventario.
# # Debe recibir el nombre del producto y la cantidad a agregar o quitar como parámetros

# %%
inventary
# Out:
# [{'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10},
#  {'nombre': 'Camisa', 'precio': 15, 'cantidad': 50}]

# %%
inventary.append({"nombre":"Calcetin", "precio": 10, "cantidad":200000})

# %%
inventary
# Out:
# [{'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10},
#  {'nombre': 'Camisa', 'precio': 15, 'cantidad': 50},
#  {'nombre': 'Calcetin', 'precio': 10, 'cantidad': 200000}]

# %%
for pantalon in inventary:
    cantidad[pantalon]+1
print(inventary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 2
#       1 for pantalon in inventary:
# ----> 2     cantidad[pantalon]+1
#       3 print(inventary)
#
# NameError: name 'cantidad' is not defined

# %%
for i in inventary:
    if inventary[i]==pantalon:
        print("pantalon"+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 2
#       1 for i in inventary:
# ----> 2     if inventary[i]==pantalon:
#       3         print("pantalon"+1)
#
# TypeError: list indices must be integers or slices, not dict

# %%
for pantalon in inventary:
    print([i]*2)
# Out:
# [{'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10}, {'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10}]
# [{'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10}, {'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10}]
# [{'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10}, {'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10}]

# %% [markdown]
# # 8 Elimina un producto del inventario por nombre. Debe recibir el
# # nombre del producto como parámetro

# %%
for camisa in inventary:
    inventary.remove({pantalon})
else:
    print(f"No hay {producto} en el inventario para eliminar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 2
#       1 for camisa in inventary:
# ----> 2     inventary.remove({pantalon})
#       3 else:
#       4     print(f"No hay {producto} en el inventario para eliminar")
#
# TypeError: unhashable type: 'dict'

# %% [markdown]
# # aqui no entiendo, todo el rato me da error porque es diccionario

# %% [markdown]
# # 9 Calcula y muestra el valor total del inventario.

# %%
inventary
# Out:
# [{'nombre': 'Pantalon', 'precio': 25, 'cantidad': 10},
#  {'nombre': 'Camisa', 'precio': 15, 'cantidad': 50},
#  {'nombre': 'Calcetin', 'precio': 10, 'cantidad': 200000}]

# %%
numeros = (10,50,200000)
for numero in numeros:
    print(10+50+200000)
# Out:
# 200060
# 200060
# 200060

# %% [markdown]
# # 10 realizar_compra(): Permite a un cliente realizar una compra seleccionando productos del
# inventario. Debe interactuar con el cliente para seleccionar productos y calcular el costo total de la
# compra.
# Utiliza un bucle while para permitir al cliente realizar múltiples compras.
# Muestra el inventario y solicita al cliente ingresar el nombre del producto que desea comprar.
# Registra los productos seleccionados en un carrito y actualiza el inventario.
# Calcula el costo total de la compra.

# %%
compra

def
